# %% [markdown]
# # Q.1

# %% [markdown]
# 1. What scale of measurement applies to timeseries data? Is timeseries data continuous or discrete? Why?

# %% [markdown]
# We use the interval scale to measure any time series data. A time series is continuous when observations are made continuously through time. A time series is discrete when observations are taken at specific times.

# %% [markdown]
# # Q.2.

# %% [markdown]
# 2. What does ARIMA stand for? Break down and explain each piece in the name.

# %% [markdown]
# ARIMA is an acronym that stands for AutoRegressive Integrated Moving Average.
# - AR: Autoregression. A model that uses the dependent relationship between an observation and some number of lagged observations.
# - I: Integrated. The use of differencing of raw observations (e.g. subtracting an observation from an observation at the previous time step) in order to make the time series stationary.
# - MA: Moving Average. A model that uses the dependency between an observation and a residual error from a moving average model applied to lagged observations.

# %% [markdown]
# # Q.3.

# %% [markdown]
# 3. Using the data in the temperatures/ folder. Write a function that efficiently converts every column to a different temperature scale: one that is more common than Kelvin.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from pprint import pprint
import seaborn as sns
import statistics
import math
from scipy import stats
temp_df = pd.read_csv("temperature.csv",parse_dates=True, index_col='datetime')
temp_df.head()
# Out:
#                       Vancouver    Portland  San Francisco     Seattle  \
# datetime
# 2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#                      Los Angeles   San Diego   Las Vegas     Phoenix  \
# datetime
# 2012-10-01 12:00:00          NaN         NaN         NaN         NaN
# 2012-10-01 13:00:00   291.870000  291.530000  293.410000  296.600000
# 2012-10-01 14:00:00   291.868185  291.533501  293.403141  296.608509
# 2012-10-01 15:00:00   291.862844  291.543355  293.392177  296.631487
# 2012-10-01 16:00:00   291.857503  291.553209  293.381213  296.654466
#
#                      Albuquerque      Denver  ...  Philadelphia    New York  \
# datetime                                      ...
# 2012-10-01 12:00:00          NaN         NaN  ...           NaN         NaN
# 2012-10-01 13:00:00   285.120000  284.610000  ...    285.630000  288.220000
# 2012-10-01 14:00:00   285.154558  284.607305  ...    285.663208  288.247676
# 2012-10-01 15:00:00   285.233952  284.599918  ...    285.756824  288.326940
# 2012-10-01 16:00:00   285.313345  284.592530  ...    285.850440  288.406203
#
#                        Montreal      Boston   Beersheba  Tel Aviv District  \
# datetime
# 2012-10-01 12:00:00         NaN         NaN         NaN                NaN
# 2012-10-01 13:00:00  285.830000  287.170000  307.590000         305.470000
# 2012-10-01 14:00:00  285.834650  287.186092  307.590000         304.310000
# 2012-10-01 15:00:00  285.847789  287.231672  307.391513         304.281841
# 2012-10-01 16:00:00  285.860929  287.277251  307.145200         304.238015
#
#                           Eilat  Haifa  Nahariyya  Jerusalem
# datetime
# 2012-10-01 12:00:00  309.100000    NaN        NaN        NaN
# 2012-10-01 13:00:00  310.580000  304.4      304.4      303.5
# 2012-10-01 14:00:00  310.495769  304.4      304.4      303.5
# 2012-10-01 15:00:00  310.411539  304.4      304.4      303.5
# 2012-10-01 16:00:00  310.327308  304.4      304.4      303.5
#
# [5 rows x 36 columns]

# %%
def Kelvin_to_Celsius(city,scale='C'):
    """Function converts the the df temp in Kelvin to Celsius"""
    try:
        if scale == 'C':
            city = city - 273.15
        else:
            print("Scale should be Celsius(C)")
    except Exception as e:
        print(e)
    return city

# %%
temp_df_cel = pd.DataFrame(index=temp_df.index)

for col in temp_df.columns:
    temp_df_cel[col] = Kelvin_to_Celsius(temp_df[col],scale='C')

# %%
display(temp_df_cel.head())
# Out:
#                      Vancouver  Portland  San Francisco   Seattle  \
# datetime
# 2012-10-01 12:00:00        NaN       NaN            NaN       NaN
# 2012-10-01 13:00:00  11.480000  8.930000      16.330000  8.650000
# 2012-10-01 14:00:00  11.479041  8.933252      16.324993  8.647217
# 2012-10-01 15:00:00  11.476998  8.941867      16.310618  8.639833
# 2012-10-01 16:00:00  11.474955  8.950481      16.296243  8.632449
#
#                      Los Angeles  San Diego  Las Vegas    Phoenix  \
# datetime
# 2012-10-01 12:00:00          NaN        NaN        NaN        NaN
# 2012-10-01 13:00:00    18.720000  18.380000  20.260000  23.450000
# 2012-10-01 14:00:00    18.718186  18.383501  20.253141  23.458509
# 2012-10-01 15:00:00    18.712845  18.393355  20.242177  23.481487
# 2012-10-01 16:00:00    18.707503  18.403209  20.231213  23.504466
#
#                      Albuquerque     Denver  ...  Philadelphia   New York  \
# datetime                                     ...
# 2012-10-01 12:00:00          NaN        NaN  ...           NaN        NaN
# 2012-10-01 13:00:00    11.970000  11.460000  ...     12.480000  15.070000
# 2012-10-01 14:00:00    12.004558  11.457306  ...     12.513208  15.097676
# 2012-10-01 15:00:00    12.083952  11.449918  ...     12.606824  15.176940
# 2012-10-01 16:00:00    12.163345  11.442530  ...     12.700441  15.256203
#
#                       Montreal     Boston  Beersheba  Tel Aviv District  \
# datetime
# 2012-10-01 12:00:00        NaN        NaN        NaN                NaN
# 2012-10-01 13:00:00  12.680000  14.020000  34.440000          32.320000
# 2012-10-01 14:00:00  12.684650  14.036092  34.440000          31.160000
# 2012-10-01 15:00:00  12.697789  14.081672  34.241513          31.131841
# 2012-10-01 16:00:00  12.710929  14.127251  33.995200          31.088015
#
#                          Eilat  Haifa  Nahariyya  Jerusalem
# datetime
# 2012-10-01 12:00:00  35.950000    NaN        NaN        NaN
# 2012-10-01 13:00:00  37.430000  31.25      31.25      30.35
# 2012-10-01 14:00:00  37.345769  31.25      31.25      30.35
# 2012-10-01 15:00:00  37.261539  31.25      31.25      30.35
# 2012-10-01 16:00:00  37.177308  31.25      31.25      30.35
#
# [5 rows x 36 columns]

# %% [markdown]
# # Q.4

# %% [markdown]
# Write a function that efficiently fills in missing values in every column, excluding trailing NANs. That is: if there's temperature data on either side of a timestamp, it should interpolate through it. But if data stopped being collected, your function should leave nans at the end.

# %%
temp_df_cel_interpolate= temp_df.interpolate(limit_area='inside')
print(temp_df_cel_interpolate.isna().sum().sum())
print(temp_df_cel.isna().sum().sum())
print(temp_df_cel_interpolate['Albuquerque'].isna())
print(temp_df_cel['Albuquerque'].isna())

temp_df_cel['Albuquerque']
# Out:
# 7955
# 8030
# datetime
# 2012-10-01 12:00:00     True
# 2012-10-01 13:00:00    False
# 2012-10-01 14:00:00    False
# 2012-10-01 15:00:00    False
# 2012-10-01 16:00:00    False
#                        ...
# 2017-11-29 20:00:00    False
# 2017-11-29 21:00:00    False
# 2017-11-29 22:00:00    False
# 2017-11-29 23:00:00    False
# 2017-11-30 00:00:00    False
# Name: Albuquerque, Length: 45253, dtype: bool
# datetime
# 2012-10-01 12:00:00     True
# 2012-10-01 13:00:00    False
# 2012-10-01 14:00:00    False
# 2012-10-01 15:00:00    False
# 2012-10-01 16:00:00    False
#                        ...
# 2017-11-29 20:00:00    False
# 2017-11-29 21:00:00    False
# 2017-11-29 22:00:00    False
# 2017-11-29 23:00:00    False
# 2017-11-30 00:00:00    False
# Name: Albuquerque, Length: 45253, dtype: bool
# datetime
# 2012-10-01 12:00:00          NaN
# 2012-10-01 13:00:00    11.970000
# 2012-10-01 14:00:00    12.004558
# 2012-10-01 15:00:00    12.083952
# 2012-10-01 16:00:00    12.163345
#                          ...
# 2017-11-29 20:00:00    12.570000
# 2017-11-29 21:00:00    13.300000
# 2017-11-29 22:00:00    13.290000
# 2017-11-29 23:00:00    12.990000
# 2017-11-30 00:00:00    11.550000
# Name: Albuquerque, Length: 45253, dtype: float64

# %% [markdown]
# # Q.5.

# %% [markdown]
# Find all cities A and B where city A is warmer than city B in the summer, but also colder than city B in the winter, on average.

# %%
temp_df_cel_interpolate['month']= pd.DatetimeIndex(temp_df_cel_interpolate.index).month
temp_df_cel_interpolate
# Out:
#                       Vancouver    Portland  San Francisco     Seattle  \
# datetime
# 2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
# ...                         ...         ...            ...         ...
# 2017-11-29 20:00:00         NaN  282.000000            NaN  280.820000
# 2017-11-29 21:00:00         NaN  282.890000            NaN  281.650000
# 2017-11-29 22:00:00         NaN  283.390000            NaN  282.750000
# 2017-11-29 23:00:00         NaN  283.020000            NaN  282.960000
# 2017-11-30 00:00:00         NaN  282.280000            NaN  283.040000
#
#                      Los Angeles   San Diego   Las Vegas     Phoenix  \
# datetime
# 2012-10-01 12:00:00          NaN         NaN         NaN         NaN
# 2012-10-01 13:00:00   291.870000  291.530000  293.410000  296.600000
# 2012-10-01 14:00:00   291.868185  291.533501  293.403141  296.608509
# 2012-10-01 15:00:00   291.862844  291.543355  293.392177  296.631487
# 2012-10-01 16:00:00   291.857503  291.553209  293.381213  296.654466
# ...                          ...         ...         ...         ...
# 2017-11-29 20:00:00   293.550000  292.150000  289.540000  294.710000
# 2017-11-29 21:00:00   295.680000  292.740000  290.610000  295.590000
# 2017-11-29 22:00:00   295.960000  292.580000  291.340000  296.250000
# 2017-11-29 23:00:00   295.650000  292.610000  292.150000  297.150000
# 2017-11-30 00:00:00   294.930000  291.400000  291.640000  297.150000
#
#                      Albuquerque      Denver  ...    New York    Montreal  \
# datetime                                      ...
# 2012-10-01 12:00:00          NaN         NaN  ...         NaN         NaN
# 2012-10-01 13:00:00   285.120000  284.610000  ...  288.220000  285.830000
# 2012-10-01 14:00:00   285.154558  284.607305  ...  288.247676  285.834650
# 2012-10-01 15:00:00   285.233952  284.599918  ...  288.326940  285.847789
# 2012-10-01 16:00:00   285.313345  284.592530  ...  288.406203  285.860929
# ...                          ...         ...  ...         ...         ...
# 2017-11-29 20:00:00   285.720000  289.560000  ...         NaN  275.130000
# 2017-11-29 21:00:00   286.450000  290.700000  ...         NaN  274.130000
# 2017-11-29 22:00:00   286.440000  289.710000  ...         NaN  273.480000
# 2017-11-29 23:00:00   286.140000  289.170000  ...         NaN  272.480000
# 2017-11-30 00:00:00   284.700000  285.180000  ...         NaN  271.800000
#
#                          Boston   Beersheba  Tel Aviv District       Eilat  \
# datetime
# 2012-10-01 12:00:00         NaN         NaN                NaN  309.100000
# 2012-10-01 13:00:00  287.170000  307.590000         305.470000  310.580000
# 2012-10-01 14:00:00  287.186092  307.590000         304.310000  310.495769
# 2012-10-01 15:00:00  287.231672  307.391513         304.281841  310.411539
# 2012-10-01 16:00:00  287.277251  307.145200         304.238015  310.327308
# ...                         ...         ...                ...         ...
# 2017-11-29 20:00:00  288.080000         NaN                NaN         NaN
# 2017-11-29 21:00:00  286.020000         NaN                NaN         NaN
# 2017-11-29 22:00:00  283.940000         NaN                NaN         NaN
# 2017-11-29 23:00:00  282.170000         NaN                NaN         NaN
# 2017-11-30 00:00:00  280.650000         NaN                NaN         NaN
#
#                      Haifa  Nahariyya  Jerusalem  month
# datetime
# 2012-10-01 12:00:00    NaN        NaN        NaN     10
# 2012-10-01 13:00:00  304.4      304.4      303.5     10
# 2012-10-01 14:00:00  304.4      304.4      303.5     10
# 2012-10-01 15:00:00  304.4      304.4      303.5     10
# 2012-10-01 16:00:00  304.4      304.4      303.5     10
# ...                    ...        ...        ...    ...
# 2017-11-29 20:00:00    NaN        NaN        NaN     11
# 2017-11-29 21:00:00    NaN        NaN        NaN     11
# 2017-11-29 22:00:00    NaN        NaN        NaN     11
# 2017-11-29 23:00:00    NaN        NaN        NaN     11
# 2017-11-30 00:00:00    NaN        NaN        NaN     11
#
# [45253 rows x 37 columns]

# %%
x=temp_df_cel_interpolate
summer_months= [5,6,7,8,9]
winter_months=[10,11,12,1,2,3,4]
x[x.month.isin(summer_months)]

#Calculated averages for cities during summer months.
avg_summer = x[x.month.isin(summer_months)].iloc[:,0:36].mean().round(2)

# %%
#Calculated averages for cities during winter months.
avg_winter =x[x.month.isin(winter_months)].iloc[:,0:36].mean().round(2)

# %%
#created dataframe with the average values and cities
average_df=pd.DataFrame(avg_summer)
average_df.columns=['summer_avg']
average_df['winter_avg']=avg_winter
average_df=average_df.reset_index()
average_df.columns=['city','summer_avg','winter_avg']
average_df
# Out:
#                  city  summer_avg  winter_avg
# 0           Vancouver      289.82      279.67
# 1            Portland      291.13      280.80
# 2       San Francisco      291.35      285.91
# 3             Seattle      289.99      280.60
# 4         Los Angeles      294.74      288.19
# 5           San Diego      293.54      287.94
# 6           Las Vegas      301.84      286.00
# 7             Phoenix      303.80      289.82
# 8         Albuquerque      293.69      280.10
# 9              Denver      291.44      276.97
# 10        San Antonio      300.04      289.51
# 11             Dallas      300.17      287.05
# 12            Houston      300.21      290.10
# 13        Kansas City      295.96      280.28
# 14        Minneapolis      292.23      272.82
# 15        Saint Louis      296.07      280.26
# 16            Chicago      292.96      276.79
# 17          Nashville      296.65      283.05
# 18       Indianapolis      294.32      278.26
# 19            Atlanta      296.94      284.88
# 20            Detroit      292.85      276.23
# 21       Jacksonville      299.49      290.81
# 22          Charlotte      296.50      283.71
# 23              Miami      300.84      296.31
# 24         Pittsburgh      292.90      278.02
# 25            Toronto      291.52      275.40
# 26       Philadelphia      294.32      279.27
# 27           New York      294.37      279.09
# 28           Montreal      291.27      272.88
# 29             Boston      292.41      277.89
# 30          Beersheba      297.04      287.64
# 31  Tel Aviv District      299.72      290.85
# 32              Eilat      303.30      291.71
# 33              Haifa      300.26      291.76
# 34          Nahariyya      298.63      290.90
# 35          Jerusalem      298.63      289.35

# %%
#Iterated inside the average df and compared which the city temp is greater in summer and for the same city temp 
#is less than in winter and print the results.
cityA=[]
cityB=[]

for i in range(len(average_df['city'])):
    city=average_df.iloc[i,0]
    summer_temp=average_df.iloc[i,1]
    winter_temp=average_df.iloc[i,2]
    for j in range(len(average_df['city'])):
        if city!=average_df.iloc[j,0]:
            if (summer_temp>average_df.iloc[j,1]) & (winter_temp<average_df.iloc[j,2]):
                cityA.append(city)
                cityB.append(average_df.iloc[j,0])
                print(city," temperature ",summer_temp," is hotter than ",average_df.iloc[j,0],average_df.iloc[j,1])
                print(city," temperature ",winter_temp," is colder than ",average_df.iloc[j,0],average_df.iloc[j,2])
# Out:
# Las Vegas  temperature  301.84  is hotter than  Los Angeles 294.74
# Las Vegas  temperature  286.0  is colder than  Los Angeles 288.19
# Las Vegas  temperature  301.84  is hotter than  San Diego 293.54
# Las Vegas  temperature  286.0  is colder than  San Diego 287.94
# Las Vegas  temperature  301.84  is hotter than  San Antonio 300.04
# Las Vegas  temperature  286.0  is colder than  San Antonio 289.51
# Las Vegas  temperature  301.84  is hotter than  Dallas 300.17
# Las Vegas  temperature  286.0  is colder than  Dallas 287.05
# Las Vegas  temperature  301.84  is hotter than  Houston 300.21
# Las Vegas  temperature  286.0  is colder than  Houston 290.1
# Las Vegas  temperature  301.84  is hotter than  Jacksonville 299.49
# Las Vegas  temperature  286.0  is colder than  Jacksonville 290.81
# Las Vegas  temperature  301.84  is hotter than  Miami 300.84
# Las Vegas  temperature  286.0  is colder than  Miami 296.31
# Las Vegas  temperature  301.84  is hotter than  Beersheba 297.04
# Las Vegas  temperature  286.0  is colder than  Beersheba 287.64
# Las Vegas  temperature  301.84  is hotter than  Tel Aviv District 299.72
# Las Vegas  temperature  286.0  is colder than  Tel Aviv District 290.85
# Las Vegas  temperature  301.84  is hotter than  Haifa 300.26
# Las Vegas  temperature  286.0  is colder than  Haifa 291.76
# Las Vegas  temperature  301.84  is hotter than  Nahariyya 298.63
# Las Vegas  temperature  286.0  is colder than  Nahariyya 290.9
# Las Vegas  temperature  301.84  is hotter than  Jerusalem 298.63
# Las Vegas  temperature  286.0  is colder than  Jerusalem 289.35
# Phoenix  temperature  303.8  is hotter than  Houston 300.21
# Phoenix  temperature  289.82  is colder than  Houston 290.1
# Phoenix  temperature  303.8  is hotter than  Jacksonville 299.49
# Phoenix  temperature  289.82  is colder than  Jacksonville 290.81
# Phoenix  temperature  303.8  is hotter than  Miami 300.84
# Phoenix  temperature  289.82  is colder than  Miami 296.31
# Phoenix  temperature  303.8  is hotter than  Tel Aviv District 299.72
# Phoenix  temperature  289.82  is colder than  Tel Aviv District 290.85
# Phoenix  temperature  303.8  is hotter than  Eilat 303.3
# Phoenix  temperature  289.82  is colder than  Eilat 291.71
# Phoenix  temperature  303.8  is hotter than  Haifa 300.26
# Phoenix  temperature  289.82  is colder than  Haifa 291.76
# Phoenix  temperature  303.8  is hotter than  Nahariyya 298.63
# Phoenix  temperature  289.82  is colder than  Nahariyya 290.9
# Albuquerque  temperature  293.69  is hotter than  Portland 291.13
# Albuquerque  temperature  280.1  is colder than  Portland 280.8
# Albuquerque  temperature  293.69  is hotter than  San Francisco 291.35
# Albuquerque  temperature  280.1  is colder than  San Francisco 285.91
# Albuquerque  temperature  293.69  is hotter than  Seattle 289.99
# Albuquerque  temperature  280.1  is colder than  Seattle 280.6
# Albuquerque  temperature  293.69  is hotter than  San Diego 293.54
# Albuquerque  temperature  280.1  is colder than  San Diego 287.94
# Denver  temperature  291.44  is hotter than  Vancouver 289.82
# Denver  temperature  276.97  is colder than  Vancouver 279.67
# Denver  temperature  291.44  is hotter than  Portland 291.13
# Denver  temperature  276.97  is colder than  Portland 280.8
# Denver  temperature  291.44  is hotter than  San Francisco 291.35
# Denver  temperature  276.97  is colder than  San Francisco 285.91
# Denver  temperature  291.44  is hotter than  Seattle 289.99
# Denver  temperature  276.97  is colder than  Seattle 280.6
# San Antonio  temperature  300.04  is hotter than  Jacksonville 299.49
# San Antonio  temperature  289.51  is colder than  Jacksonville 290.81
# San Antonio  temperature  300.04  is hotter than  Tel Aviv District 299.72
# San Antonio  temperature  289.51  is colder than  Tel Aviv District 290.85
# San Antonio  temperature  300.04  is hotter than  Nahariyya 298.63
# San Antonio  temperature  289.51  is colder than  Nahariyya 290.9
# Dallas  temperature  300.17  is hotter than  Los Angeles 294.74
# Dallas  temperature  287.05  is colder than  Los Angeles 288.19
# Dallas  temperature  300.17  is hotter than  San Diego 293.54
# Dallas  temperature  287.05  is colder than  San Diego 287.94
# Dallas  temperature  300.17  is hotter than  San Antonio 300.04
# Dallas  temperature  287.05  is colder than  San Antonio 289.51
# Dallas  temperature  300.17  is hotter than  Jacksonville 299.49
# Dallas  temperature  287.05  is colder than  Jacksonville 290.81
# Dallas  temperature  300.17  is hotter than  Beersheba 297.04
# Dallas  temperature  287.05  is colder than  Beersheba 287.64
# Dallas  temperature  300.17  is hotter than  Tel Aviv District 299.72
# Dallas  temperature  287.05  is colder than  Tel Aviv District 290.85
# Dallas  temperature  300.17  is hotter than  Nahariyya 298.63
# Dallas  temperature  287.05  is colder than  Nahariyya 290.9
# Dallas  temperature  300.17  is hotter than  Jerusalem 298.63
# Dallas  temperature  287.05  is colder than  Jerusalem 289.35
# Houston  temperature  300.21  is hotter than  Jacksonville 299.49
# Houston  temperature  290.1  is colder than  Jacksonville 290.81
# Houston  temperature  300.21  is hotter than  Tel Aviv District 299.72
# Houston  temperature  290.1  is colder than  Tel Aviv District 290.85
# Houston  temperature  300.21  is hotter than  Nahariyya 298.63
# Houston  temperature  290.1  is colder than  Nahariyya 290.9
# Kansas City  temperature  295.96  is hotter than  Portland 291.13
# Kansas City  temperature  280.28  is colder than  Portland 280.8
# Kansas City  temperature  295.96  is hotter than  San Francisco 291.35
# Kansas City  temperature  280.28  is colder than  San Francisco 285.91
# Kansas City  temperature  295.96  is hotter than  Seattle 289.99
# Kansas City  temperature  280.28  is colder than  Seattle 280.6
# Kansas City  temperature  295.96  is hotter than  Los Angeles 294.74
# Kansas City  temperature  280.28  is colder than  Los Angeles 288.19
# Kansas City  temperature  295.96  is hotter than  San Diego 293.54
# Kansas City  temperature  280.28  is colder than  San Diego 287.94
# Minneapolis  temperature  292.23  is hotter than  Vancouver 289.82
# Minneapolis  temperature  272.82  is colder than  Vancouver 279.67
# Minneapolis  temperature  292.23  is hotter than  Portland 291.13
# Minneapolis  temperature  272.82  is colder than  Portland 280.8
# Minneapolis  temperature  292.23  is hotter than  San Francisco 291.35
# Minneapolis  temperature  272.82  is colder than  San Francisco 285.91
# Minneapolis  temperature  292.23  is hotter than  Seattle 289.99
# Minneapolis  temperature  272.82  is colder than  Seattle 280.6
# Minneapolis  temperature  292.23  is hotter than  Denver 291.44
# Minneapolis  temperature  272.82  is colder than  Denver 276.97
# Minneapolis  temperature  292.23  is hotter than  Toronto 291.52
# Minneapolis  temperature  272.82  is colder than  Toronto 275.4
# Minneapolis  temperature  292.23  is hotter than  Montreal 291.27
# Minneapolis  temperature  272.82  is colder than  Montreal 272.88
# Saint Louis  temperature  296.07  is hotter than  Portland 291.13
# Saint Louis  temperature  280.26  is colder than  Portland 280.8
# Saint Louis  temperature  296.07  is hotter than  San Francisco 291.35
# Saint Louis  temperature  280.26  is colder than  San Francisco 285.91
# Saint Louis  temperature  296.07  is hotter than  Seattle 289.99
# Saint Louis  temperature  280.26  is colder than  Seattle 280.6
# Saint Louis  temperature  296.07  is hotter than  Los Angeles 294.74
# Saint Louis  temperature  280.26  is colder than  Los Angeles 288.19
# Saint Louis  temperature  296.07  is hotter than  San Diego 293.54
# Saint Louis  temperature  280.26  is colder than  San Diego 287.94
# Saint Louis  temperature  296.07  is hotter than  Kansas City 295.96
# Saint Louis  temperature  280.26  is colder than  Kansas City 280.28
# Chicago  temperature  292.96  is hotter than  Vancouver 289.82
# Chicago  temperature  276.79  is colder than  Vancouver 279.67
# Chicago  temperature  292.96  is hotter than  Portland 291.13
# Chicago  temperature  276.79  is colder than  Portland 280.8
# Chicago  temperature  292.96  is hotter than  San Francisco 291.35
# Chicago  temperature  276.79  is colder than  San Francisco 285.91
# Chicago  temperature  292.96  is hotter than  Seattle 289.99
# Chicago  temperature  276.79  is colder than  Seattle 280.6
# Chicago  temperature  292.96  is hotter than  Denver 291.44
# Chicago  temperature  276.79  is colder than  Denver 276.97
# Chicago  temperature  292.96  is hotter than  Pittsburgh 292.9
# Chicago  temperature  276.79  is colder than  Pittsburgh 278.02
# Chicago  temperature  292.96  is hotter than  Boston 292.41
# Chicago  temperature  276.79  is colder than  Boston 277.89
# Nashville  temperature  296.65  is hotter than  San Francisco 291.35
# Nashville  temperature  283.05  is colder than  San Francisco 285.91
# Nashville  temperature  296.65  is hotter than  Los Angeles 294.74
# Nashville  temperature  283.05  is colder than  Los Angeles 288.19
# Nashville  temperature  296.65  is hotter than  San Diego 293.54
# Nashville  temperature  283.05  is colder than  San Diego 287.94
# Nashville  temperature  296.65  is hotter than  Charlotte 296.5
# Nashville  temperature  283.05  is colder than  Charlotte 283.71
# Indianapolis  temperature  294.32  is hotter than  Vancouver 289.82
# Indianapolis  temperature  278.26  is colder than  Vancouver 279.67
# Indianapolis  temperature  294.32  is hotter than  Portland 291.13
# Indianapolis  temperature  278.26  is colder than  Portland 280.8
# Indianapolis  temperature  294.32  is hotter than  San Francisco 291.35
# Indianapolis  temperature  278.26  is colder than  San Francisco 285.91
# Indianapolis  temperature  294.32  is hotter than  Seattle 289.99
# Indianapolis  temperature  278.26  is colder than  Seattle 280.6
# Indianapolis  temperature  294.32  is hotter than  San Diego 293.54
# Indianapolis  temperature  278.26  is colder than  San Diego 287.94
# Indianapolis  temperature  294.32  is hotter than  Albuquerque 293.69
# Indianapolis  temperature  278.26  is colder than  Albuquerque 280.1
# Atlanta  temperature  296.94  is hotter than  San Francisco 291.35
# Atlanta  temperature  284.88  is colder than  San Francisco 285.91
# Atlanta  temperature  296.94  is hotter than  Los Angeles 294.74
# Atlanta  temperature  284.88  is colder than  Los Angeles 288.19
# Atlanta  temperature  296.94  is hotter than  San Diego 293.54
# Atlanta  temperature  284.88  is colder than  San Diego 287.94
# Detroit  temperature  292.85  is hotter than  Vancouver 289.82
# Detroit  temperature  276.23  is colder than  Vancouver 279.67
# Detroit  temperature  292.85  is hotter than  Portland 291.13
# Detroit  temperature  276.23  is colder than  Portland 280.8
# Detroit  temperature  292.85  is hotter than  San Francisco 291.35
# Detroit  temperature  276.23  is colder than  San Francisco 285.91
# Detroit  temperature  292.85  is hotter than  Seattle 289.99
# Detroit  temperature  276.23  is colder than  Seattle 280.6
# Detroit  temperature  292.85  is hotter than  Denver 291.44
# Detroit  temperature  276.23  is colder than  Denver 276.97
# Detroit  temperature  292.85  is hotter than  Boston 292.41
# Detroit  temperature  276.23  is colder than  Boston 277.89
# Jacksonville  temperature  299.49  is hotter than  Nahariyya 298.63
# Jacksonville  temperature  290.81  is colder than  Nahariyya 290.9
# Charlotte  temperature  296.5  is hotter than  San Francisco 291.35
# Charlotte  temperature  283.71  is colder than  San Francisco 285.91
# Charlotte  temperature  296.5  is hotter than  Los Angeles 294.74
# Charlotte  temperature  283.71  is colder than  Los Angeles 288.19
# Charlotte  temperature  296.5  is hotter than  San Diego 293.54
# Charlotte  temperature  283.71  is colder than  San Diego 287.94
# Pittsburgh  temperature  292.9  is hotter than  Vancouver 289.82
# Pittsburgh  temperature  278.02  is colder than  Vancouver 279.67
# Pittsburgh  temperature  292.9  is hotter than  Portland 291.13
# Pittsburgh  temperature  278.02  is colder than  Portland 280.8
# Pittsburgh  temperature  292.9  is hotter than  San Francisco 291.35
# Pittsburgh  temperature  278.02  is colder than  San Francisco 285.91
# Pittsburgh  temperature  292.9  is hotter than  Seattle 289.99
# Pittsburgh  temperature  278.02  is colder than  Seattle 280.6
# Toronto  temperature  291.52  is hotter than  Vancouver 289.82
# Toronto  temperature  275.4  is colder than  Vancouver 279.67
# Toronto  temperature  291.52  is hotter than  Portland 291.13
# Toronto  temperature  275.4  is colder than  Portland 280.8
# Toronto  temperature  291.52  is hotter than  San Francisco 291.35
# Toronto  temperature  275.4  is colder than  San Francisco 285.91
# Toronto  temperature  291.52  is hotter than  Seattle 289.99
# Toronto  temperature  275.4  is colder than  Seattle 280.6
# Toronto  temperature  291.52  is hotter than  Denver 291.44
# Toronto  temperature  275.4  is colder than  Denver 276.97
# Philadelphia  temperature  294.32  is hotter than  Vancouver 289.82
# Philadelphia  temperature  279.27  is colder than  Vancouver 279.67
# Philadelphia  temperature  294.32  is hotter than  Portland 291.13
# Philadelphia  temperature  279.27  is colder than  Portland 280.8
# Philadelphia  temperature  294.32  is hotter than  San Francisco 291.35
# Philadelphia  temperature  279.27  is colder than  San Francisco 285.91
# Philadelphia  temperature  294.32  is hotter than  Seattle 289.99
# Philadelphia  temperature  279.27  is colder than  Seattle 280.6
# Philadelphia  temperature  294.32  is hotter than  San Diego 293.54
# Philadelphia  temperature  279.27  is colder than  San Diego 287.94
# Philadelphia  temperature  294.32  is hotter than  Albuquerque 293.69
# Philadelphia  temperature  279.27  is colder than  Albuquerque 280.1
# New York  temperature  294.37  is hotter than  Vancouver 289.82
# New York  temperature  279.09  is colder than  Vancouver 279.67
# New York  temperature  294.37  is hotter than  Portland 291.13
# New York  temperature  279.09  is colder than  Portland 280.8
# New York  temperature  294.37  is hotter than  San Francisco 291.35
# New York  temperature  279.09  is colder than  San Francisco 285.91
# New York  temperature  294.37  is hotter than  Seattle 289.99
# New York  temperature  279.09  is colder than  Seattle 280.6
# New York  temperature  294.37  is hotter than  San Diego 293.54
# New York  temperature  279.09  is colder than  San Diego 287.94
# New York  temperature  294.37  is hotter than  Albuquerque 293.69
# New York  temperature  279.09  is colder than  Albuquerque 280.1
# New York  temperature  294.37  is hotter than  Philadelphia 294.32
# New York  temperature  279.09  is colder than  Philadelphia 279.27
# Montreal  temperature  291.27  is hotter than  Vancouver 289.82
# Montreal  temperature  272.88  is colder than  Vancouver 279.67
# Montreal  temperature  291.27  is hotter than  Portland 291.13
# Montreal  temperature  272.88  is colder than  Portland 280.8
# Montreal  temperature  291.27  is hotter than  Seattle 289.99
# Montreal  temperature  272.88  is colder than  Seattle 280.6
# Boston  temperature  292.41  is hotter than  Vancouver 289.82
# Boston  temperature  277.89  is colder than  Vancouver 279.67
# Boston  temperature  292.41  is hotter than  Portland 291.13
# Boston  temperature  277.89  is colder than  Portland 280.8
# Boston  temperature  292.41  is hotter than  San Francisco 291.35
# Boston  temperature  277.89  is colder than  San Francisco 285.91
# Boston  temperature  292.41  is hotter than  Seattle 289.99
# Boston  temperature  277.89  is colder than  Seattle 280.6
# Beersheba  temperature  297.04  is hotter than  Los Angeles 294.74
# Beersheba  temperature  287.64  is colder than  Los Angeles 288.19
# Beersheba  temperature  297.04  is hotter than  San Diego 293.54
# Beersheba  temperature  287.64  is colder than  San Diego 287.94
# Tel Aviv District  temperature  299.72  is hotter than  Nahariyya 298.63
# Tel Aviv District  temperature  290.85  is colder than  Nahariyya 290.9
# Eilat  temperature  303.3  is hotter than  Miami 300.84
# Eilat  temperature  291.71  is colder than  Miami 296.31
# Eilat  temperature  303.3  is hotter than  Haifa 300.26
# Eilat  temperature  291.71  is colder than  Haifa 291.76

# %% [markdown]
# # Q.6.

# %% [markdown]
# For two of the cities you found in question 5 (there are many possible answers), clean up the data via rolling averages and plot a clear visual. Explain how rolling average differs from moving average (MA) model.

# %%
temp_df_cel_interpolate[["New York","San Francisco"]].rolling('30D').mean().plot(title="Temperature over the years in New York and San Francisco")
plt.xlabel("Year")
plt.ylabel("Temperature (Celsius)")
plt.show()

# %% [markdown]
# Rolling average takes average of the data points within a selected window. In the above case a window of 30 calendar days was selected to calculate average temperature, for the specified city and year.
#
# Moving average model is used for future prediction using time series analysis. When the output data is linearly dependent on the past and present values, we need to use the moving average model. Because of this MA model assumes equal weights for all data points unlike the rolling average.

# %% [markdown]
# # Q.7.

# %% [markdown]
# Perform SARIMA on five cities, iterating through the cities programmatically. Explain your results.

# %%
#Taking five cities after the comparison
sarima_df = temp_df_cel.loc[:,['Los Angeles','Atlanta','Seattle','Houston','Chicago']]

# %%
#importing neccessary modules for sarimax
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
import warnings
warnings.filterwarnings('ignore')
#useful to set equal to 'once'

# %%
sarima_diff=sarima_df.copy(deep=False)

for i in sarima_df:
    #converting non stationary into stationary by taking seasonal and non seasonal difference
    #sarima_df[i].plot()
    sarima_diff["diff_"+i]=sarima_df[i].diff().diff(7).dropna()
    sarima_diff=sarima_diff.dropna()
    #plotting acf,pacf
    plot_acf(sarima_diff[["diff_"+i]],zero=False,lags=10,missing='drop',title="ACF for "+i);
    plot_pacf(sarima_diff[["diff_"+i]],lags=10,method='ywm',title="PACF for "+i);
    #creating SARIMA model
    model=SARIMAX(sarima_diff["diff_"+i],order=(5,1,0),seasonal_order=(2,1,0,12))
    fitting_model=model.fit(low_memory=True)
    print(fitting_model.summary())
    #forecasting for next 30 days
    forecast_df=pd.DataFrame(fitting_model.forecast(steps=5))
    forecast_df.plot()
    plt.title("Forecasting for 30 days out for "+i)
    plt.xlabel('Year')
    plt.ylabel('Temperature in Celsius')
